# %% [markdown]
# # **Trabalhando com Planilhas do Excel**

# %%
# Importando a biblioteca
import pandas as pd

# %%
# Leitura dos arquivos
df1 = pd.read_excel("/content/drive/MyDrive/Datasets/AdventureWorks.xlsx")
df2 = pd.read_excel("/content/drive/MyDrive/Datasets/Aracaju.xlsx")
df3 = pd.read_excel("/content/drive/MyDrive/Datasets/Fortaleza.xlsx")
df4 = pd.read_excel("/content/drive/MyDrive/Datasets/Natal.xlsx")
df5 = pd.read_excel("/content/drive/MyDrive/Datasets/Salvador.xlsx")

# %%
df1.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 1  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 2  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 3  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 4  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor
# 0  Regular  Red
# 1  Regular  Red
# 2  Regular  Red
# 3  Regular  Red
# 4  Regular  Red

# %%
# Juntando todos os arquivos
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29    199.0       384.0     18839.0  200805093CS607
# 1 2008-05-12 2008-05-17    306.0       384.0     19051.0  200805123CS567
# 2 2008-05-14 2008-05-20    306.0       384.0     19052.0  200805143CS576
# 3 2008-05-21 2008-05-27    306.0       384.0     19052.0  200805213CS576
# 4 2008-06-20 2008-06-27    306.0       384.0     19053.0  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 0          348.58           758.0         6.0             0.0  ...
# 1          348.58           758.0         6.0             0.0  ...
# 2          348.58           758.0         6.0             0.0  ...
# 3          348.58           758.0         6.0             0.0  ...
# 4          348.58           758.0         6.0             0.0  ...
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 1  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 2  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 3  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 4  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor Cidade Data Vendas  LojaID  Qtde
# 0  Regular  Red    NaN  NaT    NaN     NaN   NaN
# 1  Regular  Red    NaN  NaT    NaN     NaN   NaN
# 2  Regular  Red    NaN  NaT    NaN     NaN   NaN
# 3  Regular  Red    NaN  NaT    NaN     NaN   NaN
# 4  Regular  Red    NaN  NaT    NaN     NaN   NaN
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente No. Venda  \
# 235        NaT        NaT      NaN         NaN         NaN       NaN
# 236        NaT        NaT      NaN         NaN         NaN       NaN
# 237        NaT        NaT      NaN         NaN         NaN       NaN
# 238        NaT        NaT      NaN         NaN         NaN       NaN
# 239        NaT        NaT      NaN         NaN         NaN       NaN
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  Produto  \
# 235             NaN             NaN         NaN             NaN  ...      NaN
# 236             NaN             NaN         NaN             NaN  ...      NaN
# 237             NaN             NaN         NaN             NaN  ...      NaN
# 238             NaN             NaN         NaN             NaN  ...      NaN
# 239             NaN             NaN         NaN             NaN  ...      NaN
#
#     Fabricante Marca Classe  Cor    Cidade       Data  Vendas  LojaID  Qtde
# 235        NaN   NaN    NaN  NaN  Salvador 2019-01-03   41.84  1034.0   1.0
# 236        NaN   NaN    NaN  NaN  Salvador 2019-01-03  126.29  1035.0   3.0
# 237        NaN   NaN    NaN  NaN  Salvador 2019-01-03   38.06  1036.0   3.0
# 238        NaN   NaN    NaN  NaN  Salvador 2019-01-03  139.64  1035.0   1.0
# 239        NaN   NaN    NaN  NaN  Salvador 2019-01-03  161.41  1037.0   3.0
#
# [5 rows x 21 columns]

# %%
# Obtendo uma amostra do conjunto de dados
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 895 2009-01-11 2009-01-18    307.0      1155.0     19113.0  200901114CS680
# 163        NaT        NaT      NaN         NaN         NaN             NaN
# 113 2009-04-10 2009-04-15    199.0      1155.0     18931.0  200904104CS840
# 7          NaT        NaT      NaN         NaN         NaN             NaN
# 476 2009-11-07 2009-11-17    306.0       366.0     19076.0  200911073CS767
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 895          324.69           980.0         6.0           882.0  ...
# 163             NaN             NaN         NaN             NaN  ...
# 113          324.69           980.0         6.0             0.0  ...
# 7               NaN             NaN         NaN             NaN  ...
# 476          348.58           758.0        12.0          1819.2  ...
#
#                                         Produto       Fabricante  \
# 895  Fabrikam Trendsetter 2/3'' 17mm X100 Black   Fabrikam, Inc.
# 163                                         NaN              NaN
# 113  Fabrikam Trendsetter 2/3'' 17mm X100 Black   Fabrikam, Inc.
# 7                                           NaN              NaN
# 476     Adventure Works Laptop15.4W M1548 Black  Adventure Works
#
#                Marca   Classe    Cor    Cidade       Data  Vendas  LojaID  \
# 895         Fabrikam  Regular  Black       NaN        NaT     NaN     NaN
# 163              NaN      NaN    NaN  Salvador 2019-01-02   17.66  1036.0
# 113         Fabrikam  Regular  Black       NaN        NaT     NaN     NaN
# 7                NaN      NaN    NaN     Natal 2019-03-18  886.00   853.0
# 476  Adventure Works  Regular  Black       NaN        NaT     NaN     NaN
#
#      Qtde
# 895   NaN
# 163   3.0
# 113   NaN
# 7     4.0
# 476   NaN
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                  float64
# ID Produto               float64
# ID Cliente               float64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade               float64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                   float64
# Qtde                     float64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                  float64
# ID Produto               float64
# ID Cliente               float64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade               float64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                    object
# Qtde                     float64
# dtype: object

# %% [markdown]
# # **Tratando valores faltantes**

# %%
# Consultando linhas com valores faltantes
df.isnull().sum()
# Out:
# Data Venda        752
# Data Envio        752
# ID Loja           752
# ID Produto        752
# ID Cliente        752
# No. Venda         752
# Custo Unitário    752
# Preço Unitário    752
# Quantidade        752
# Valor Desconto    752
# Valor Venda       752
# Produto           752
# Fabricante        752
# Marca             752
# Classe            752
# Cor               752
# Cidade            904
# Data              904
# Vendas            904
# LojaID            904
# Qtde              904
# dtype: int64

# %%
df["Vendas"].mean()
# Out:
# 130.97852393617023

# %%
# Substituindo os valores nulos pela média
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Data Venda        752
# Data Envio        752
# ID Loja           752
# ID Produto        752
# ID Cliente        752
# No. Venda         752
# Custo Unitário    752
# Preço Unitário    752
# Quantidade        752
# Valor Desconto    752
# Valor Venda       752
# Produto           752
# Fabricante        752
# Marca             752
# Classe            752
# Cor               752
# Cidade            904
# Data              904
# Vendas              0
# LojaID            904
# Qtde              904
# dtype: int64

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 31         NaT        NaT      NaN         NaN         NaN             NaN
# 205        NaT        NaT      NaN         NaN         NaN             NaN
# 237        NaT        NaT      NaN         NaN         NaN             NaN
# 186        NaT        NaT      NaN         NaN         NaN             NaN
# 191 2009-05-24 2009-06-03    199.0       366.0     18946.0  200905243CS856
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 31              NaN             NaN         NaN             NaN  ...
# 205             NaN             NaN         NaN             NaN  ...
# 237             NaN             NaN         NaN             NaN  ...
# 186             NaN             NaN         NaN             NaN  ...
# 191          348.58           758.0        12.0             0.0  ...
#
#                                      Produto       Fabricante  \
# 31                                       NaN              NaN
# 205                                      NaN              NaN
# 237                                      NaN              NaN
# 186                                      NaN              NaN
# 191  Adventure Works Laptop15.4W M1548 Black  Adventure Works
#
#                Marca   Classe    Cor     Cidade       Data      Vendas  \
# 31               NaN      NaN    NaN  Fortaleza 2019-01-01   23.460000
# 205              NaN      NaN    NaN   Salvador 2019-01-02  196.090000
# 237              NaN      NaN    NaN   Salvador 2019-01-03   38.060000
# 186              NaN      NaN    NaN   Salvador 2019-01-02  169.090000
# 191  Adventure Works  Regular  Black        NaN        NaT  130.978524
#
#      LojaID Qtde
# 31   1002.0  4.0
# 205  1037.0  1.0
# 237  1036.0  3.0
# 186  1036.0  2.0
# 191     NaN  NaN
#
# [5 rows x 21 columns]

# %%
# Substituindo os valores nulos por zero
df["Vendas"].fillna(0, inplace=True)

# %%
# Apagando as linhas com os valores nulos com base apenas em uma coluna
df.dropna(subset=["Vendas"], inplace=True)

# %%
# Removendo linhas que estejam com valores faltantes em todas as colunas
df.dropna(how="all", inplace=True)

# %% [markdown]
# # **Criando colunas novas**

# %%
# Criando a coluna de receita
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29    199.0       384.0     18839.0  200805093CS607
# 1 2008-05-12 2008-05-17    306.0       384.0     19051.0  200805123CS567
# 2 2008-05-14 2008-05-20    306.0       384.0     19052.0  200805143CS576
# 3 2008-05-21 2008-05-27    306.0       384.0     19052.0  200805213CS576
# 4 2008-06-20 2008-06-27    306.0       384.0     19053.0  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 0          348.58           758.0         6.0             0.0  ...
# 1          348.58           758.0         6.0             0.0  ...
# 2          348.58           758.0         6.0             0.0  ...
# 3          348.58           758.0         6.0             0.0  ...
# 4          348.58           758.0         6.0             0.0  ...
#
#         Fabricante            Marca   Classe  Cor Cidade Data      Vendas  \
# 0  Adventure Works  Adventure Works  Regular  Red    NaN  NaT  130.978524
# 1  Adventure Works  Adventure Works  Regular  Red    NaN  NaT  130.978524
# 2  Adventure Works  Adventure Works  Regular  Red    NaN  NaT  130.978524
# 3  Adventure Works  Adventure Works  Regular  Red    NaN  NaT  130.978524
# 4  Adventure Works  Adventure Works  Regular  Red    NaN  NaT  130.978524
#
#   LojaID  Qtde Receita
# 0    NaN   NaN     NaN
# 1    NaN   NaN     NaN
# 2    NaN   NaN     NaN
# 3    NaN   NaN     NaN
# 4    NaN   NaN     NaN
#
# [5 rows x 22 columns]

# %%
df["Receita/Vendas"] = df["Receita"] / df["Vendas"]

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29    199.0       384.0     18839.0  200805093CS607
# 1 2008-05-12 2008-05-17    306.0       384.0     19051.0  200805123CS567
# 2 2008-05-14 2008-05-20    306.0       384.0     19052.0  200805143CS576
# 3 2008-05-21 2008-05-27    306.0       384.0     19052.0  200805213CS576
# 4 2008-06-20 2008-06-27    306.0       384.0     19053.0  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 0          348.58           758.0         6.0             0.0  ...
# 1          348.58           758.0         6.0             0.0  ...
# 2          348.58           758.0         6.0             0.0  ...
# 3          348.58           758.0         6.0             0.0  ...
# 4          348.58           758.0         6.0             0.0  ...
#
#              Marca   Classe  Cor Cidade Data      Vendas LojaID Qtde  Receita  \
# 0  Adventure Works  Regular  Red    NaN  NaT  130.978524    NaN  NaN      NaN
# 1  Adventure Works  Regular  Red    NaN  NaT  130.978524    NaN  NaN      NaN
# 2  Adventure Works  Regular  Red    NaN  NaT  130.978524    NaN  NaN      NaN
# 3  Adventure Works  Regular  Red    NaN  NaT  130.978524    NaN  NaN      NaN
# 4  Adventure Works  Regular  Red    NaN  NaT  130.978524    NaN  NaN      NaN
#
#   Receita/Vendas
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 23 columns]

# %%
# Retornando a maior receita
df["Receita"].max()
# Out:
# 3544.0

# %%
df["Receita"].min()
# Out:
# 3.34

# %%
# Descobrindo a 3 maiores receitas
df.nlargest(3, "Receita")
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente No. Venda  \
# 7         NaT        NaT      NaN         NaN         NaN       NaN
# 51        NaT        NaT      NaN         NaN         NaN       NaN
# 55        NaT        NaT      NaN         NaN         NaN       NaN
#
#     Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  Marca  \
# 7              NaN             NaN         NaN             NaN  ...    NaN
# 51             NaN             NaN         NaN             NaN  ...    NaN
# 55             NaN             NaN         NaN             NaN  ...    NaN
#
#    Classe  Cor Cidade       Data Vendas LojaID Qtde  Receita Receita/Vendas
# 7     NaN  NaN  Natal 2019-03-18  886.0  853.0  4.0   3544.0            4.0
# 51    NaN  NaN  Natal 2018-01-21  859.0  852.0  4.0   3436.0            4.0
# 55    NaN  NaN  Natal 2019-01-08  859.0  854.0  4.0   3436.0            4.0
#
# [3 rows x 23 columns]

# %%
# Descobrindo a 3 menores receitas
df.nsmallest(3, "Receita")
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente No. Venda  \
# 118        NaT        NaT      NaN         NaN         NaN       NaN
# 92         NaT        NaT      NaN         NaN         NaN       NaN
# 92         NaT        NaT      NaN         NaN         NaN       NaN
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  Marca  \
# 118             NaN             NaN         NaN             NaN  ...    NaN
# 92              NaN             NaN         NaN             NaN  ...    NaN
# 92              NaN             NaN         NaN             NaN  ...    NaN
#
#     Classe  Cor    Cidade       Data Vendas  LojaID Qtde  Receita  \
# 118    NaN  NaN   Aracaju 2018-01-01   3.34  1522.0  1.0     3.34
# 92     NaN  NaN     Natal 2019-01-02   4.57  1035.0  1.0     4.57
# 92     NaN  NaN  Salvador 2019-01-01   4.57  1035.0  1.0     4.57
#
#     Receita/Vendas
# 118            1.0
# 92             1.0
# 92             1.0
#
# [3 rows x 23 columns]

# %%
# Agrupamento por cidade
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
# Ordenando o conjunto de dados
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente No. Venda  \
# 7         NaT        NaT      NaN         NaN         NaN       NaN
# 51        NaT        NaT      NaN         NaN         NaN       NaN
# 55        NaT        NaT      NaN         NaN         NaN       NaN
# 30        NaT        NaT      NaN         NaN         NaN       NaN
# 41        NaT        NaT      NaN         NaN         NaN       NaN
# 10        NaT        NaT      NaN         NaN         NaN       NaN
# 38        NaT        NaT      NaN         NaN         NaN       NaN
# 69        NaT        NaT      NaN         NaN         NaN       NaN
# 62        NaT        NaT      NaN         NaN         NaN       NaN
# 52        NaT        NaT      NaN         NaN         NaN       NaN
#
#     Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  Marca  \
# 7              NaN             NaN         NaN             NaN  ...    NaN
# 51             NaN             NaN         NaN             NaN  ...    NaN
# 55             NaN             NaN         NaN             NaN  ...    NaN
# 30             NaN             NaN         NaN             NaN  ...    NaN
# 41             NaN             NaN         NaN             NaN  ...    NaN
# 10             NaN             NaN         NaN             NaN  ...    NaN
# 38             NaN             NaN         NaN             NaN  ...    NaN
# 69             NaN             NaN         NaN             NaN  ...    NaN
# 62             NaN             NaN         NaN             NaN  ...    NaN
# 52             NaN             NaN         NaN             NaN  ...    NaN
#
#    Classe  Cor Cidade       Data Vendas LojaID Qtde  Receita Receita/Vendas
# 7     NaN  NaN  Natal 2019-03-18  886.0  853.0  4.0   3544.0            4.0
# 51    NaN  NaN  Natal 2018-01-21  859.0  852.0  4.0   3436.0            4.0
# 55    NaN  NaN  Natal 2019-01-08  859.0  854.0  4.0   3436.0            4.0
# 30    NaN  NaN  Natal 2018-10-02  856.0  853.0  4.0   3424.0            4.0
# 41    NaN  NaN  Natal 2018-05-20  835.0  852.0  4.0   3340.0            4.0
# 10    NaN  NaN  Natal 2018-10-27  828.0  852.0  4.0   3312.0            4.0
# 38    NaN  NaN  Natal 2018-02-25  828.0  852.0  4.0   3312.0            4.0
# 69    NaN  NaN  Natal 2019-03-24  817.0  852.0  4.0   3268.0            4.0
# 62    NaN  NaN  Natal 2018-02-10  793.0  854.0  4.0   3172.0            4.0
# 52    NaN  NaN  Natal 2018-04-27  778.0  854.0  4.0   3112.0            4.0
#
# [10 rows x 23 columns]

# %% [markdown]
# # **Trabalhando com datas**

# %%
#Transformando a coluna em data do tipo inteiro
df["Data"] = df["Data"].astype("int64")
# Out:
# <ipython-input-31-0fcc935f2b96>:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   df["Data"] = df["Data"].astype("int64")

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                  float64
# ID Produto               float64
# ID Cliente               float64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade               float64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# Cidade                    object
# Data                       int64
# Vendas                   float64
# LojaID                    object
# Qtde                     float64
# Receita                  float64
# Receita/Vendas           float64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                  float64
# ID Produto               float64
# ID Cliente               float64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade               float64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                    object
# Qtde                     float64
# Receita                  float64
# Receita/Vendas           float64
# dtype: object

# %%
# Agrupamento por ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018.0    118176.53
# 2019.0    176309.94
# Name: Receita, dtype: float64

# %%
# Criando uma nova coluna com o ano
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 870 2009-12-20 2009-12-25    199.0       366.0     19031.0  200912203CS947
# 141 2009-04-12 2009-04-17    199.0       366.0     18931.0  200904123CS840
# 716 2009-03-18 2009-03-30    307.0      2496.0     19118.0  200903185CS708
# 44         NaT        NaT      NaN         NaN         NaN             NaN
# 635 2009-02-05 2009-02-11    199.0      1155.0     18912.0  200902054CS820
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...   Classe  \
# 870          348.58          758.00         6.0         909.600  ...  Regular
# 141          348.58          758.00         6.0           0.000  ...  Regular
# 716            5.09            9.99       216.0         431.568  ...  Economy
# 44              NaN             NaN         NaN             NaN  ...      NaN
# 635          324.69          980.00         5.0         245.000  ...  Regular
#
#         Cor    Cidade       Data      Vendas  LojaID Qtde Receita  \
# 870   Black       NaN        NaT  130.978524     NaN  NaN     NaN
# 141   Black       NaN        NaT  130.978524     NaN  NaN     NaN
# 716  Silver       NaN        NaT  130.978524     NaN  NaN     NaN
# 44      NaN  Salvador 2019-01-01   43.260000  1037.0  2.0   86.52
# 635   Black       NaN        NaT  130.978524     NaN  NaN     NaN
#
#      Receita/Vendas Ano_Venda
# 870             NaN       NaN
# 141             NaN       NaN
# 716             NaN       NaN
# 44              2.0    2019.0
# 635             NaN       NaN
#
# [5 rows x 24 columns]

# %%
# Extraindo o mês e o dia
df["Mes_Venda"], df["Dia_Venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 135        NaT        NaT      NaN         NaN         NaN             NaN
# 580 2008-07-21 2008-07-31    199.0      1203.0     18856.0  200807214CS645
# 613 2009-02-20 2009-02-27    306.0       366.0     19063.0  200902203CS740
# 78         NaT        NaT      NaN         NaN         NaN             NaN
# 195        NaT        NaT      NaN         NaN         NaN             NaN
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 135             NaN             NaN         NaN             NaN  ...
# 580          324.69           980.0         8.0          784.00  ...
# 613          348.58           758.0         8.0          424.48  ...
# 78              NaN             NaN         NaN             NaN  ...
# 195             NaN             NaN         NaN             NaN  ...
#
#         Cidade       Data      Vendas  LojaID Qtde Receita Receita/Vendas  \
# 135  Fortaleza 2019-03-02   10.790000   983.0  5.0   53.95            5.0
# 580        NaN        NaT  130.978524     NaN  NaN     NaN            NaN
# 613        NaN        NaT  130.978524     NaN  NaN     NaN            NaN
# 78    Salvador 2019-01-01  111.200000  1036.0  3.0  333.60            3.0
# 195      Natal 2019-01-02   44.890000  1036.0  3.0  134.67            3.0
#
#     Ano_Venda  Mes_Venda Dia_Venda
# 135    2019.0        3.0       2.0
# 580       NaN        NaN       NaN
# 613       NaN        NaN       NaN
# 78     2019.0        1.0       1.0
# 195    2019.0        1.0       2.0
#
# [5 rows x 26 columns]

# %%
# Retornando a data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Calculando a diferença de dias
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 172 2009-06-02 2009-06-15    199.0      1203.0     18949.0  200906024CS859
# 848 2008-03-22 2008-04-04    306.0      1203.0     19049.0  200803224CS555
# 183        NaT        NaT      NaN         NaN         NaN             NaN
# 750 2009-10-26 2009-11-05    306.0      2497.0     19076.0  200910265CS767
# 40         NaT        NaT      NaN         NaN         NaN             NaN
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 172          324.69          980.00        12.0           0.000  ...
# 848          324.69          980.00         6.0         411.600  ...
# 183             NaN             NaN         NaN             NaN  ...
# 750            5.09            9.99       384.0         767.232  ...
# 40              NaN             NaN         NaN             NaN  ...
#
#           Data      Vendas  LojaID Qtde Receita Receita/Vendas Ano_Venda  \
# 172        NaT  130.978524     NaN  NaN     NaN            NaN       NaN
# 848        NaT  130.978524     NaN  NaN     NaN            NaN       NaN
# 183 2019-01-02  120.230000  1037.0  2.0  240.46            2.0    2019.0
# 750        NaT  130.978524     NaN  NaN     NaN            NaN       NaN
# 40  2019-02-13  161.870000  1036.0  3.0  485.61            3.0    2019.0
#
#     Mes_Venda  Dia_Venda diferenca_dias
# 172       NaN        NaN            NaT
# 848       NaN        NaN            NaT
# 183       1.0        2.0       366 days
# 750       NaN        NaN            NaT
# 40        2.0       13.0       408 days
#
# [5 rows x 27 columns]

# %%
# Criando a coluna de trimestre
df["trimestre_vendas"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 179        NaT        NaT      NaN         NaN         NaN             NaN
# 132 2008-06-19 2008-06-30    199.0       366.0     18847.0  200806193CS619
# 158        NaT        NaT      NaN         NaN         NaN             NaN
# 359 2009-03-28 2009-04-10    307.0      1202.0     19119.0  200903284CS709
# 562 2008-11-06 2008-11-18    307.0       384.0     19108.0  200811063CS648
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  \
# 179             NaN             NaN         NaN             NaN  ...
# 132          348.58           758.0         6.0             0.0  ...
# 158             NaN             NaN         NaN             NaN  ...
# 359          330.66           998.0        15.0          2994.0  ...
# 562          348.58           758.0         8.0           909.6  ...
#
#          Vendas  LojaID Qtde Receita Receita/Vendas Ano_Venda Mes_Venda  \
# 179   64.950000  1036.0  1.0   64.95            1.0    2019.0       1.0
# 132  130.978524     NaN  NaN     NaN            NaN       NaN       NaN
# 158  183.640000  1037.0  3.0  550.92            3.0    2019.0       1.0
# 359  130.978524     NaN  NaN     NaN            NaN       NaN       NaN
# 562  130.978524     NaN  NaN     NaN            NaN       NaN       NaN
#
#     Dia_Venda  diferenca_dias trimestre_vendas
# 179       2.0        366 days              1.0
# 132       NaN             NaT              NaN
# 158       2.0        366 days              1.0
# 359       NaN             NaT              NaN
# 562       NaN             NaT              NaN
#
# [5 rows x 28 columns]

# %%
# Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) &(df["Data"].dt.month == 3)]

# %%
vendas_marco_19
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente No. Venda  \
# 108        NaT        NaT      NaN         NaN         NaN       NaN
# 109        NaT        NaT      NaN         NaN         NaN       NaN
# 110        NaT        NaT      NaN         NaN         NaN       NaN
# 111        NaT        NaT      NaN         NaN         NaN       NaN
# 112        NaT        NaT      NaN         NaN         NaN       NaN
# ..         ...        ...      ...         ...         ...       ...
# 137        NaT        NaT      NaN         NaN         NaN       NaN
# 138        NaT        NaT      NaN         NaN         NaN       NaN
# 139        NaT        NaT      NaN         NaN         NaN       NaN
# 140        NaT        NaT      NaN         NaN         NaN       NaN
# 141        NaT        NaT      NaN         NaN         NaN       NaN
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  ...  Vendas  \
# 108             NaN             NaN         NaN             NaN  ...  152.89
# 109             NaN             NaN         NaN             NaN  ...   18.90
# 110             NaN             NaN         NaN             NaN  ...   51.98
# 111             NaN             NaN         NaN             NaN  ...    8.00
# 112             NaN             NaN         NaN             NaN  ...  133.59
# ..              ...             ...         ...             ...  ...     ...
# 137             NaN             NaN         NaN             NaN  ...   51.66
# 138             NaN             NaN         NaN             NaN  ...  212.03
# 139             NaN             NaN         NaN             NaN  ...  169.01
# 140             NaN             NaN         NaN             NaN  ...   20.79
# 141             NaN             NaN         NaN             NaN  ...    9.08
#
#      LojaID Qtde Receita Receita/Vendas Ano_Venda Mes_Venda Dia_Venda  \
# 108   981.0  4.0  611.56            4.0    2019.0       3.0       2.0
# 109   982.0  6.0  113.40            6.0    2019.0       3.0       2.0
# 110   983.0  6.0  311.88            6.0    2019.0       3.0       2.0
# 111   981.0  3.0   24.00            3.0    2019.0       3.0       2.0
# 112   982.0  1.0  133.59            1.0    2019.0       3.0       2.0
# ..      ...  ...     ...            ...       ...       ...       ...
# 137  1036.0  3.0  154.98            3.0    2019.0       3.0       2.0
# 138  1037.0  3.0  636.09            3.0    2019.0       3.0       2.0
# 139  1036.0  1.0  169.01            1.0    2019.0       3.0       2.0
# 140  1036.0  2.0   41.58            2.0    2019.0       3.0       2.0
# 141  1036.0  1.0    9.08            1.0    2019.0       3.0       2.0
#
#      diferenca_dias trimestre_vendas
# 108        425 days              1.0
# 109        425 days              1.0
# 110        425 days              1.0
# 111        425 days              1.0
# 112        425 days              1.0
# ..              ...              ...
# 137        425 days              1.0
# 138        425 days              1.0
# 139        425 days              1.0
# 140        425 days              1.0
# 141        425 days              1.0
#
# [87 rows x 28 columns]

# %% [markdown]
# # **Visualização de dados**

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036.0    117
# 1035.0    112
# 1037.0    101
# 1034.0     67
# 1522.0     41
# 1520.0     39
# 1005.0     30
# 1002.0     30
# 852.0      29
# 1523.0     29
# 1004.0     28
# 854.0      28
# 853.0      26
# 1521.0     21
# 1003.0     20
# 983.0      13
# 982.0      10
# 981.0       6
# 980.0       5
# Name: LojaID, dtype: int64

# %%
# Gráfico de barras
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
# Gráfico de barras horizontais
df["LojaID"].value_counts(ascending=False).plot.barh();

# %%
# Gráfico de pizza
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie();

# %%
# Total de vendas por cidade
df["Cidade"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 235    Salvador
# 236    Salvador
# 237    Salvador
# 238    Salvador
# 239    Salvador
# Name: Cidade, Length: 1656, dtype: object>

# %%
# Adicionando um título e alterando o nome dos eixos
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total de vendas por cidade")
plt.xlabel("Cidade")
plt.ylabel("Total de vendas");

# %%
# Alterando a cor
df["Cidade"].value_counts().plot.bar(title="Total de vendas por cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total de vendas");

# %%
# Alterando o estilo
plt.style.use("ggplot")

# %%
df.groupby(df["Mes_Venda"])["Qtde"].sum().plot(title="Total de Produtos Vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos")
plt.legend();

# %%
df.groupby(df["Mes_Venda"])["Qtde"].sum()
# Out:
# Mes_Venda
# 1.0     1753.0
# 2.0      102.0
# 3.0      297.0
# 4.0       23.0
# 5.0       17.0
# 6.0       13.0
# 7.0       13.0
# 8.0        2.0
# 9.0       10.0
# 10.0      14.0
# 11.0       2.0
# 12.0       3.0
# Name: Qtde, dtype: float64

# %%
# Selecionando apenas as vendas de 2019
df_2019 = df[df["Ano_Venda"] == 2019]

# %%
# Total de produtos vendidos por mês
df_2019.groupby(df_2019["Mes_Venda"])["Qtde"].sum().plot(marker="o")
plt.xlabel = "Mês"
plt.ylabel = "Total de produtos vendidos"
plt.legend();

# %%
df_2019.groupby(df_2019["Mes_Venda"])["Qtde"].sum()
# Out:
# Mes_Venda
# 1.0    1086.0
# 2.0      86.0
# 3.0     290.0
# 4.0      12.0
# Name: Qtde, dtype: float64

# %%
# Histograma
plt.hist(df["Qtde"], color="orangered");

# %%
# Gráfico de dispersão
plt.scatter(x = df_2019["Dia_Venda"], y = df_2019["Receita"]);

# %%
# Salvando em png
df_2019.groupby(df_2019["Mes_Venda"])["Qtde"].sum().plot(marker = "v")
plt.title("Quantidade de Produtos Vendidos X Mês")
plt.xlabel = "Mês"
plt.ylabel = "Total de produtos vendidos"
plt.legend()
plt.savefig("grafico qtde x mes.png")
